# %% [markdown]
# ## Scraper pour la prévision météo

# %% [markdown]
# ### Utilisation:

# %%
! scrapy crawl weather
# Out:
# /Users/anilnarassiguin/MeetupDS/DS_appliquee_scraping/weather_prediction/weather_prediction/spiders/weather_spider.py:4: ScrapyDeprecationWarning: Module `scrapy.spider` is deprecated, use `scrapy.spiders` instead
#   from scrapy.spider import BaseSpider
# /Users/anilnarassiguin/MeetupDS/DS_appliquee_scraping/weather_prediction/weather_prediction/spiders/weather_spider.py:13: ScrapyDeprecationWarning: weather_prediction.spiders.weather_spider.WeatherSpider inherits from deprecated class scrapy.spiders.BaseSpider, please inherit from scrapy.spiders.Spider. (warning only on first subclass, there may be others)
#   class WeatherSpider(BaseSpider):
# 2016-05-10 18:21:08 [scrapy] INFO: Scrapy 1.0.3 started (bot: weather_prediction)
# 2016-05-10 18:21:08 [scrapy] INFO: Optional features available: ssl, http11, boto
# ...

# %% [markdown]
# ### Résultat :

# %%
! cat ./output/result.csv
# Out:
# time,temperature,wind_direction,wind_speed,gust,rain,humidity,pressure,weather
# 17:00 10/05/2016,23 °C,Sud-Sud-Ouest : 194 °,30,40,0.6 mm,58 %,1007 hPa,Risque d'orage faible
# 20:00 10/05/2016,19 °C,Sud-Sud-Ouest : 192 °,15,30,--,70 %,1007 hPa,Mitigé
# 23:00 10/05/2016,14 °C,Sud-Sud-Est : 159 °,10,--,--,79 %,1007 hPa,Couvert
# 02:00 11/05/2016,14 °C,Sud-Sud-Est : 163 °,10,--,--,80 %,1007 hPa,Couvert
# 05:00 11/05/2016,13 °C,Sud-Sud-Ouest : 211 °,5,--,2.4 mm,92 %,1006 hPa,Pluie modérée
# 08:00 11/05/2016,12 °C,Nord-Ouest : 315 °,5,--,6.2 mm,92 %,1005 hPa,Pluie forte
# 11:00 11/05/2016,13 °C,Nord-Nord-Est : 21 °,5,--,1.9 mm,88 %,1004 hPa,Pluie faible
# 14:00 11/05/2016,19 °C,Sud-Sud-Est : 166 °,10,--,--,69 %,1002 hPa,Couvert
# 17:00 11/05/2016,19 °C,Sud : 173 °,15,--,--,73 %,1000 hPa,Couvert
# 20:00 11/05/2016,15 °C,Sud : 174 °,10,--,7.6 mm,94 %,1000 hPa,Pluie forte
# 23:00 11/05/2016,13 °C,Sud-Sud-Ouest : 195 °,5,--,6.1 mm,94 %,1001 hPa,Averses de pluie fortes
# ...
